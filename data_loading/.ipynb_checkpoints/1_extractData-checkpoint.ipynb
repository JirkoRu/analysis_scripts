# %% [markdown]
# # Import CSV files, combine them and extract Numpy arrays

# %%
import numpy as np
import pandas as pd
import os
import glob

# %% [markdown]
# ### Import files into pd.DataFrame

# %%
dname = os.getcwd() + '/../../data/'
dname
# Out:
# '/home/jacques/Documents/2022_AudioGeometry/audioGeometryShapes/audioGeometryDimsWithEncouragements/analysis/0_example/../../data/'

# %%
fnames = glob.glob(dname + 'raw/*.txt')
fnames = fnames[:10]
fnames
# Out:
# ['/home/jacques/Documents/2022_AudioGeometry/audioGeometryShapes/audioGeometryDimsWithEncouragements/analysis/0_example/../../data/raw/4vuyjr4a1r.txt',
#  '/home/jacques/Documents/2022_AudioGeometry/audioGeometryShapes/audioGeometryDimsWithEncouragements/analysis/0_example/../../data/raw/178u9ukh6h.txt',
#  '/home/jacques/Documents/2022_AudioGeometry/audioGeometryShapes/audioGeometryDimsWithEncouragements/analysis/0_example/../../data/raw/6ua8vhepdq.txt',
#  '/home/jacques/Documents/2022_AudioGeometry/audioGeometryShapes/audioGeometryDimsWithEncouragements/analysis/0_example/../../data/raw/2kxu48oebt.txt',
#  '/home/jacques/Documents/2022_AudioGeometry/audioGeometryShapes/audioGeometryDimsWithEncouragements/analysis/0_example/../../data/raw/uflc9s94en.txt',
#  '/home/jacques/Documents/2022_AudioGeometry/audioGeometryShapes/audioGeometryDimsWithEncouragements/analysis/0_example/../../data/raw/93ssmohgwx.txt',
# ...

# %%
DF = pd.DataFrame()
for i, fname in enumerate(fnames):

    # Read CSV
    _df = pd.read_csv(fname)
    
    # Append to the big dataFrame
    DF = DF.append(_df, ignore_index=True)

# %% [markdown]
# ### Explore DataFrame

# %%
pd.set_option('display.max_columns', None)
DF.head(15)
# Out:
#     data : "rt"                                           stimulus response  \
# 0        6090.0                      Click to start the experiment        0
# 1        7194.0  <p align='left'> \n                <b>INTRODUC...        0
# 2       17159.0  <p align='left'> \n                <b>INSTRUCT...        0
# 3       15208.0                         stim_global/disclaimer.png        0
# 4           NaN                                                NaN      NaN
# 5           NaN                                                NaN      NaN
# 6           NaN                                  stim_set_1/11.wav      NaN
# 7           NaN                                  stim_set_1/21.wav      NaN
# 8           NaN                                  stim_set_1/22.wav      NaN
# 9           NaN                                  stim_set_1/12.wav      NaN
# 10       3030.0                                                NaN        0
# ...

# %% [markdown]
# ### Filter responses

# %%
# Flter only response trials
DF = DF.loc[DF['trial_response'] == True]

# %%
DF.head(2)
# Out:
#     data : "rt" stimulus response            trial_type  trial_index  \
# 10       3030.0      NaN        0  html-button-response           10
# 18       2058.0      NaN        1  html-button-response           18
#
#     time_elapsed internal_node_id success timeout failed_images failed_audio  \
# 10         52889  0.0-1.0-1.0-6.0     NaN     NaN           NaN          NaN
# 18         59304  0.0-1.0-1.0-6.1     NaN     NaN           NaN          NaN
#
#    failed_video          id     sex    age                    turker  \
# 10          NaN  4vuyjr4a1r  female  21-30  5e446fed821464000b318348
# 18          NaN  4vuyjr4a1r  female  21-30  5e446fed821464000b318348
#
#       sound_system           task modality condition_dimension  \
# 10  computer sound  AudioGeometry    audio                  2D
# 18  computer sound  AudioGeometry    audio                  2D
#
#             condition_training  bloc_index bloc_type  bloc_n_trials  \
# ...

# %% [markdown]
# ### Save full DataFrame to CSV

# %%
DF.to_csv(dname + 'full_data.csv')

# %% [markdown]
# ### Retreive parameters

# %%
sujs = DF['id'].unique()
n_sujs = sujs.size
n_sujs
# Out:
# 10

# %%
n_trials_per_suj = DF.loc[DF['id'] == sujs[0]].shape[0]
n_trials_per_suj
# Out:
# 600

# %%
n_blocs = DF['bloc_index'].unique().size
n_blocs
# Out:
# 12

# %%
n_trials_training = int(DF.loc[DF['bloc_type'] == 'training', 'bloc_n_trials'].unique()[0])
n_trials_generalization = int(DF.loc[DF['bloc_type'] == 'generalization', 'bloc_n_trials'].unique()[0])
n_trials = np.max([n_trials_training, n_trials_generalization])
n_trials
# Out:
# 60

# %% [markdown]
# ### Put data in numpy arrays

# %%
ACCURACY = np.full((n_sujs, n_blocs, n_trials), np.nan)
RT = np.full((n_sujs, n_blocs, n_trials), np.nan)
BLOC_TYPE = np.full((n_sujs, n_blocs), np.nan, dtype=np.object)

# Loop across participant and blocs
for i, suj in enumerate(sujs):
    for j in range(n_blocs):

        # Select lines in the DataFrame
        _DF = DF.loc[(DF['id'] == suj) & (DF['bloc_index'] == j)]

        # Accuracy 
        ACCURACY[i, j, :_DF.shape[0]] = _DF['response_accuracy']

        # Reaction times
        RT[i, j, :_DF.shape[0]] = _DF['data : "rt"']
        
        # Bloc type
        BLOC_TYPE[i, j] = _DF['bloc_type'].unique()[0]

# %% [markdown]
# ### Save data as arrays

# %%
np.save(dname + 'ACCURACY.npy', ACCURACY)
np.save(dname + 'RT.npy', RT)
np.save(dname + 'BLOC_TYPE.npy', BLOC_TYPE)
np.save(dname + 'SUJS.npy', sujs)
